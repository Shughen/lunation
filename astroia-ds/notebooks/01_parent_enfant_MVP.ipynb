# %% [markdown]
# # 🤖 Analyse Parent-Enfant - MVP
#
# Notebook d'exploration et entraînement XGBoost

# %%
# Cellule 1 - Setup
# !python -V

# %%
# Cellule 2 - Imports & Data
import pandas as pd
import os

df = pd.read_csv("../data_external/dataset.csv")
print("Shape:", df.shape)
df.head()

# %%
# Cellule 3 - Entraînement rapide
# !python ../src/train.py --data ../data_external/dataset.csv --target target --rounds 1000

# %%
# Cellule 4 - Résultats
import json
import pprint
import joblib

print("Files:", os.listdir("../outputs"))
print("\nMetrics:")
pprint.pprint(json.load(open("../outputs/metrics.json")))

model = joblib.load("../outputs/models/xgb_model.pkl")
print("\nModel:", model)
